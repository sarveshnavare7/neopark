# %%
#using google colab
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pl=pd.read_excel("Plot.xlsx")
pl
# Out:
#          X          Y
# 0      190   8.001296
# 1      191   9.903781
# 2      192  12.486976
# 3      193  14.808269
# 4      194  14.616501
# ...    ...        ...
# 2306  2496  64.907333
# 2307  2497  65.241524
# 2308  2498  65.523911
# 2309  2499  65.012863
# 2310  2500  64.636787
#
# [2311 rows x 2 columns]

# %%
x = pl['X']  
y = pl['Y']  
plt.plot(x, y)  
plt.xlabel("Xaxis")
plt.ylabel("yaxis")
plt.show()

# %%
df=pd.read_csv("D1.csv")

# %%
df
# Out:
#      Unnamed: 0       100       101       102  ...       799     A     B          C
# 0             1  0.338689  0.338454  0.338232  ...  0.372568  0.30  0.22        NaN
# 1             2  0.308191  0.307937  0.307680  ...  0.316818  0.69   NaN        NaN
# 2             3  0.327993  0.327722  0.327448  ...  0.342632  0.71   NaN        NaN
# 3             4  0.364145  0.363900  0.363639  ...  0.365806  0.85   NaN        NaN
# 4             5  0.237328  0.237091  0.236838  ...  0.306401   NaN  0.90        NaN
# ..          ...       ...       ...       ...  ...       ...   ...   ...        ...
# 820         821  0.584903  0.584770  0.584582  ...  0.572968  8.80  6.30  22.299999
# 821         822  0.481173  0.480568  0.479973  ...  0.672984  3.80  3.43  34.500000
# 822         823  0.556911  0.556547  0.556198  ...  0.581226  7.20  7.97  33.299999
# 823         824  0.514596  0.514150  0.513720  ...  0.708540  5.90  5.66  40.700001
# ...

# %%
df1=df
df1=df1.drop(columns=['B','C'])
df1
# Out:
#      Unnamed: 0       100       101  ...       798       799     A
# 0             1  0.338689  0.338454  ...  0.372459  0.372568  0.30
# 1             2  0.308191  0.307937  ...  0.316480  0.316818  0.69
# 2             3  0.327993  0.327722  ...  0.342218  0.342632  0.71
# 3             4  0.364145  0.363900  ...  0.365499  0.365806  0.85
# 4             5  0.237328  0.237091  ...  0.305823  0.306401   NaN
# ..          ...       ...       ...  ...       ...       ...   ...
# 820         821  0.584903  0.584770  ...  0.572930  0.572968  8.80
# 821         822  0.481173  0.480568  ...  0.672374  0.672984  3.80
# 822         823  0.556911  0.556547  ...  0.581041  0.581226  7.20
# 823         824  0.514596  0.514150  ...  0.708020  0.708540  5.90
# 824         825  0.583532  0.583189  ...  0.734171  0.734480  8.00
#
# [825 rows x 702 columns]

# %%
df2=df
df2=df2.drop(columns=['A','C'])
df2
# Out:
#      Unnamed: 0       100       101  ...       798       799     B
# 0             1  0.338689  0.338454  ...  0.372459  0.372568  0.22
# 1             2  0.308191  0.307937  ...  0.316480  0.316818   NaN
# 2             3  0.327993  0.327722  ...  0.342218  0.342632   NaN
# 3             4  0.364145  0.363900  ...  0.365499  0.365806   NaN
# 4             5  0.237328  0.237091  ...  0.305823  0.306401  0.90
# ..          ...       ...       ...  ...       ...       ...   ...
# 820         821  0.584903  0.584770  ...  0.572930  0.572968  6.30
# 821         822  0.481173  0.480568  ...  0.672374  0.672984  3.43
# 822         823  0.556911  0.556547  ...  0.581041  0.581226  7.97
# 823         824  0.514596  0.514150  ...  0.708020  0.708540  5.66
# 824         825  0.583532  0.583189  ...  0.734171  0.734480  7.76
#
# [825 rows x 702 columns]

# %%
df3=df
df3=df3.drop(columns=['A','B'])
df3
# Out:
#      Unnamed: 0       100       101  ...       798       799          C
# 0             1  0.338689  0.338454  ...  0.372459  0.372568        NaN
# 1             2  0.308191  0.307937  ...  0.316480  0.316818        NaN
# 2             3  0.327993  0.327722  ...  0.342218  0.342632        NaN
# 3             4  0.364145  0.363900  ...  0.365499  0.365806        NaN
# 4             5  0.237328  0.237091  ...  0.305823  0.306401        NaN
# ..          ...       ...       ...  ...       ...       ...        ...
# 820         821  0.584903  0.584770  ...  0.572930  0.572968  22.299999
# 821         822  0.481173  0.480568  ...  0.672374  0.672984  34.500000
# 822         823  0.556911  0.556547  ...  0.581041  0.581226  33.299999
# 823         824  0.514596  0.514150  ...  0.708020  0.708540  40.700001
# 824         825  0.583532  0.583189  ...  0.734171  0.734480  46.299999
#
# [825 rows x 702 columns]

# %%
df1.dropna(subset = ["A"], inplace=True)
df1=df1.sort_values("A")
df1
# Out:
#      Unnamed: 0       100       101  ...       798       799     A
# 759         760  0.329941  0.329492  ...  0.339990  0.340262  0.20
# 226         227  0.283710  0.283224  ...  0.297265  0.297569  0.20
# 618         619  0.219230  0.218476  ...  0.418144  0.418907  0.22
# 0             1  0.338689  0.338454  ...  0.372459  0.372568  0.30
# 762         763  0.300777  0.300099  ...  0.409095  0.409785  0.30
# ..          ...       ...       ...  ...       ...       ...   ...
# 616         617  0.704280  0.703952  ...  0.886679  0.886990  7.90
# 824         825  0.583532  0.583189  ...  0.734171  0.734480  8.00
# 617         618  0.699217  0.698876  ...  0.886301  0.886748  8.10
# 401         402  0.458562  0.458203  ...  0.496057  0.496469  8.10
# 820         821  0.584903  0.584770  ...  0.572930  0.572968  8.80
#
# [645 rows x 702 columns]

# %%
df2.dropna(subset = ["B"], inplace=True)
df2=df2.sort_values("B")
df2
# Out:
#      Unnamed: 0       100       101  ...       798       799          B
# 196         197  0.359959  0.359718  ...  0.403486  0.403685   0.100000
# 338         339  0.298510  0.298155  ...  0.340052  0.340614   0.100000
# 728         729  0.310848  0.310518  ...  0.333870  0.334375   0.100000
# 731         732  0.258148  0.257524  ...  0.351250  0.351695   0.100000
# 337         338  0.309944  0.309182  ...  0.400609  0.401231   0.100000
# ..          ...       ...       ...  ...       ...       ...        ...
# 485         486  0.762546  0.762319  ...  0.697485  0.697552  10.800000
# 615         616  0.591090  0.590874  ...  0.578662  0.578751  11.100000
# 788         789  0.807625  0.807336  ...  0.690031  0.689979  11.979999
# 569         570  0.761152  0.760828  ...  0.666677  0.666722  14.960000
# 584         585  0.783462  0.783125  ...  0.678006  0.677940  17.229999
#
# [732 rows x 702 columns]

# %%
df3.dropna(subset = ["C"], inplace=True)
df3=df3.sort_values("C")
df3
# Out:
#      Unnamed: 0       100       101  ...       798       799          C
# 196         197  0.359959  0.359718  ...  0.403486  0.403685   1.000000
# 37           38  0.370148  0.369085  ...  0.345711  0.346040   1.400000
# 38           39  0.267122  0.266875  ...  0.235792  0.236104   1.500000
# 125         126  0.291656  0.290798  ...  0.299273  0.300002   2.100000
# 665         666  0.312089  0.310711  ...  0.350296  0.350842   2.400000
# ..          ...       ...       ...  ...       ...       ...        ...
# 615         616  0.591090  0.590874  ...  0.578662  0.578751  40.000000
# 823         824  0.514596  0.514150  ...  0.708020  0.708540  40.700001
# 616         617  0.704280  0.703952  ...  0.886679  0.886990  45.099998
# 617         618  0.699217  0.698876  ...  0.886301  0.886748  45.700001
# 824         825  0.583532  0.583189  ...  0.734171  0.734480  46.299999
#
# [447 rows x 702 columns]

# %%
plt.figure(figsize=(15,15)) 
plt.hist([df1['A'],df2['B'],df3['C']],edgecolor='black',histtype='bar')
# plt.hist(df2['B'],edgecolor='black',histtype='bar')
# plt.hist(df3['C'],edgecolor='black',histtype='bar')
plt.legend(['A','B','C'])
plt.xlabel("Value")
plt.ylabel("Frequency")
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0, 0.5, 'Frequency')

# %%
df1.to_csv("D1_1.csv")
df2.to_csv("D1_2.csv")
df3.to_csv("D1_3.csv")
